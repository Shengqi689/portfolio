# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Shengqi Ma
#
# Student ID: 1262480

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Monday, 27 March 2023 1pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -10% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See "Using Jupyter Notebook and Python" page on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, Gensim, Keras and Pytorch. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3.8</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=https://www.nltk.org/book/>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place. In regards to the use of artificial intelligence tools in the context of academic integrity, please see the university's statement <a href="https://academicintegrity.unimelb.edu.au/plagiarism-and-collusion/artificial-intelligence-tools-and-technologies">here</a>.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection of tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation (based on frequency). The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English letters in the alphabet (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet (represented using a python dictionary). For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
nltk.download('stopwords')
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase

def preprocess_data(data, labels):
    
    ###
    # Your answer BEGINS HERE
    ###
    import re
    x_processed = []
    y_processed = []
    for tweet, label in zip(data,labels):
      # tokenize
      new_tweet= tt.tokenize(tweet)
      bag_words = {}
      for word in new_tweet:
        # lowercase
        word = word.lower()
        # remove non-English words and stopwords
        if re.search("[a-z]",word) and not word in stopwords:
          # count frequency of each word
          bag_words[word] = bag_words.get(word,0) + 1
      if bag_words:
        x_processed.append(bag_words)
        y_processed.append(label)
    return x_processed, y_processed

    ###
    # Your answer ENDS HERE
    ###

x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = {'@addictd2success': 1, 'thx': 1, 'u': 1, 'following': 1}
# Country = us 	Tweet = {"let's": 1, 'say': 1, 'ever': 1, 'switch': 1, 'teams': 1, 'khalesi': 1, 'would': 1, 'top': 1, 'list': 1, '#girlcrush': 1}
# Country = ph 	Tweet = {'taemin': 1, 'jonghyun': 1, 'birits': 1, 'make': 1, 'go': 1, 'http://t.co/le8z3dntla': 1}
# Country = id 	Tweet = {'depart.senior': 1, 'rapat': 1, 'perdana': 1, 'nyayu': 1, 'anita': 1, 'others': 1, 'ruang': 1, 'aescullap': 1, 'fk': 1, 'unsri': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1}
# Country = ph 	Tweet = {'done': 1, 'internship': 1, 'pretty': 1, 'little': 1, 'lady': 1, 'metropolitan': 1, 'medical': 1, 'center': 1, 'w': 1, 'others': 1, 'pic': 1, 'http://t.co/1qh61r1t5r': 1}
# Country = gb 	Tweet = {'wow': 1, "boruc's": 1, 'clanger': 1, 'haha': 1, 'sunday': 1, 'league': 1, 'stuff': 1, 'giroud': 1, 'believe': 1, 'luck': 1, '#clown': 1}
# Country = my 	Tweet = {"i'm": 1, 'sushi': 1, 'zanmai': 1, 'petaling': 1, 'jaya': 1, 'selangor': 1, 'w': 1, 'others': 1, 'http://t.co/bcnobykz': 1}
# Country = us 	Tweet = {'mega': 1, 'fest': 1, 'going': 1, '@bishopjakes': 1}
# Country = gb 	Tweet = {'@ellexxxpharrell': 1, 'wow': 1, 'love': 1, 'pic': 1, 'babe': 1, 'xx': 1}
# Country = us 	Tweet = {'clue': 1, 'much': 1, 'hurt': 1}

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecords", the algorithm should produce: \["#", "new", "records"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
from nltk.corpus import wordnet
nltk.download('words')
nltk.download('wordnet')

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words = set([ word.lower() for word in words ]) #lowercase all the words for better matching

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma


def tokenize_hashtags(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    dict = {}
    for hashtag in hashtags:
      # key="hashtag" and value="a list of tokenised words"
      key = hashtag
      tok_words = []
      while len(key) > 0:
        # default to matching a single letter in the worst case
        letter = key[0]
        sub_key = key[1:]
        # match by MaxMatch algorithm, stop when max match is found
        for i in range(len(key)-1,-1,-1):
          tok_word = key[:i+1]
          unmatched_word = key[i+1:]
          if lemmatize(tok_word) in words:
            letter = tok_word
            sub_key = unmatched_word
            break
        tok_words.append(letter)
        key = sub_key
      dict[hashtag] = tok_words
    return dict

    ###
    # Your answer ENDS HERE
    ###

#tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

#print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'coca', 'm']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e', '9', '0', 's']
# #wearesocial ['#', 'weares', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
def tokenize_hashtags_rev(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    dict = {}
    for hashtag in hashtags:
      # key="hashtag" and value="a list of tokenised words"
      key = hashtag
      tok_words = []
      while len(key) > 0:
        # default to matching a single letter in the worst case
        letter = key[-1]
        sub_key = key[:-1]
        # match by MaxMatch algorithm, stop when max match is found
        for i in range(0,len(key)):
          tok_word = key[i:]
          unmatched_word = key[:i]
          if lemmatize(tok_word) in words:
            letter = tok_word
            sub_key = unmatched_word
            break
        tok_words.append(letter)
        key = sub_key
      # reverse the order of a list of tokenized words
      tok_words.reverse()
      dict[hashtag] = tok_words
    return dict

    ###
    # Your answer ENDS HERE
    ###

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'gan']
# #veganfood ['#', 'v', 'e', 'gan', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'c', 'o', 'cam']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'we', 'are', '9', '0', 's']
# #wearesocial ['#', 'we', 'are', 'social']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'a', 'mas']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i> = P(<i>#</i>)\*P(<i>hellow</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
import nltk
nltk.download('brown')

#words from brown corpus
brown_words = brown.words()

###
# Your answer BEGINS HERE
###
import collections
import math
# lowercase all words in the corpus
brown_words = [word.lower() for word in brown_words]
# add-one smoothing by the unigram language model
count_vocab = len(set(brown_words))
count_corpus = len(brown_words)
count_words = collections.Counter(brown_words)
tags = sorted(hashtags)
for tag in tags:
  tok_words = tokenized_hashtags[tag]
  rev_tok_words = tokenized_hashtags_rev[tag]
  if tok_words != rev_tok_words:
    p_list = []
    for x in tok_words:
      p = math.log((count_words[x]+1)/(count_vocab+count_corpus))
      p_list.append(p)
    result = math.prod(p_list)
    rev_p_list = []
    for y in rev_tok_words:
      rev_p = math.log((count_words[y]+1)/(count_vocab+count_corpus))
      rev_p_list.append(rev_p)
    rev_result = math.prod(rev_p_list) 
    print(". ", tag) 
    print("MaxMatch = ", tok_words, "; LogProb = ", result) 
    print("Reversed MaxMatch = ", rev_tok_words, "; LogProb = ", rev_result) 
    print()

###
# Your answer ENDS HERE
###
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# .  #1stsundayofoctober
# MaxMatch =  ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r'] ; LogProb =  266000309.80465218
# Reversed MaxMatch =  ['#', '1', 'st', 'sunday', 'of', 'october'] ; LogProb =  501898.9522216603
#
# .  #1yearofalmostisneverenough
# MaxMatch =  ['#', '1', 'year', 'of', 'almost', 'is', 'never', 'enough'] ; LogProb =  6421782.684768583
# Reversed MaxMatch =  ['#', '1', 'year', 'of', 'al', 'mos', 'tis', 'never', 'enough'] ; LogProb =  -356572919.74253315
#
# .  #8thannualpubcrawl
# MaxMatch =  ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl'] ; LogProb =  204567694.1526712
# Reversed MaxMatch =  ['#', '8', 'th', 'annual', 'pub', 'crawl'] ; LogProb =  2658606.139476513
#
# .  #affsuzukicup
# MaxMatch =  ['#', 'a', 'f', 'fs', 'u', 'z', 'u', 'k', 'i', 'cup'] ; LogProb =  8211844405.853145
# Reversed MaxMatch =  ['#', 'a', 'f', 'f', 'suz', 'u', 'k', 'i', 'cup'] ; LogProb =  -614791286.8267452
#
# .  #ahimacon14
# MaxMatch =  ['#', 'ah', 'ima', 'con', '1', '4'] ; LogProb =  1707572.8220825752
# Reversed MaxMatch =  ['#', 'a', 'hi', 'macon', '1', '4'] ; LogProb =  556017.5937898057
#
# .  #alliswell
# MaxMatch =  ['#', 'all', 'is', 'well'] ; LogProb =  2898.5178892287963
# Reversed MaxMatch =  ['#', 'al', 'li', 'swell'] ; LogProb =  25153.63817984211
#
# .  #allwedoiscurls
# MaxMatch =  ['#', 'all', 'wed', 'o', 'is', 'curls'] ; LogProb =  740359.0111646856
# Reversed MaxMatch =  ['#', 'all', 'w', 'edo', 'is', 'curls'] ; LogProb =  916180.760102555
#
# .  #anferneehardaway
# MaxMatch =  ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay'] ; LogProb =  360075921.3080581
# Reversed MaxMatch =  ['#', 'an', 'f', 'er', 'nee', 'hard', 'away'] ; LogProb =  -11315566.388862431
#
# .  #ariona
# MaxMatch =  ['#', 'arion', 'a'] ; LogProb =  -775.9959210064908
# Reversed MaxMatch =  ['#', 'ar', 'i', 'ona'] ; LogProb =  14997.191853115542
#
# .  #arte
# MaxMatch =  ['#', 'art', 'e'] ; LogProb =  -1249.2587029112358
# Reversed MaxMatch =  ['#', 'ar', 'te'] ; LogProb =  -2748.0961646085802
#
# .  #askherforfback
# MaxMatch =  ['#', 'ask', 'her', 'for', 'f', 'back'] ; LogProb =  275874.4445922587
# Reversed MaxMatch =  ['#', 'ask', 'her', 'f', 'orf', 'back'] ; LogProb =  796904.0747385847
#
# .  #askolly
# MaxMatch =  ['#', 'ask', 'o', 'l', 'ly'] ; LogProb =  -214786.91753313632
# Reversed MaxMatch =  ['#', 'as', 'kol', 'ly'] ; LogProb =  14063.80665658603
#
# .  #asksteven
# MaxMatch =  ['#', 'asks', 'te', 'v', 'en'] ; LogProb =  -276344.241517358
# Reversed MaxMatch =  ['#', 'ask', 'steven'] ; LogProb =  -1794.6252361064007
#
# .  #bedimages
# MaxMatch =  ['#', 'bedim', 'ages'] ; LogProb =  -1972.881875737469
# Reversed MaxMatch =  ['#', 'bed', 'images'] ; LogProb =  -1329.6941963903719
#
# .  #beringmy
# MaxMatch =  ['#', 'beri', 'n', 'g', 'my'] ; LogProb =  -154697.46731221038
# Reversed MaxMatch =  ['#', 'be', 'ring', 'my'] ; LogProb =  5081.4871377739355
#
# .  #bettybooppose
# MaxMatch =  ['#', 'betty', 'boo', 'p', 'pose'] ; LogProb =  -262046.22723150463
# Reversed MaxMatch =  ['#', 'betty', 'bo', 'oppose'] ; LogProb =  26440.9924399649
#
# .  #blackhat
# MaxMatch =  ['#', 'black', 'hat'] ; LogProb =  -1212.6508589631198
# Reversed MaxMatch =  ['#', 'b', 'lac', 'khat'] ; LogProb =  25676.901667954222
#
# .  #blessedmorethanicanimagine
# MaxMatch =  ['#', 'blessed', 'more', 'than', 'i', 'can', 'imagine'] ; LogProb =  -2301582.079289352
# Reversed MaxMatch =  ['#', 'blessed', 'more', 'th', 'ani', 'can', 'imagine'] ; LogProb =  -11701814.522924248
#
# .  #blessedsunday
# MaxMatch =  ['#', 'blesseds', 'un', 'day'] ; LogProb =  16667.61638954838
# Reversed MaxMatch =  ['#', 'blessed', 'sunday'] ; LogProb =  -1493.8926627555702
#
# .  #blogtourambiente
# MaxMatch =  ['#', 'blo', 'g', 'tour', 'ambient', 'e'] ; LogProb =  3231156.835587707
# Reversed MaxMatch =  ['#', 'b', 'log', 'tou', 'ram', 'bien', 'te'] ; LogProb =  -50844723.9077618
#
# .  #booyaa
# MaxMatch =  ['#', 'boo', 'ya', 'a'] ; LogProb =  9144.353156959358
# Reversed MaxMatch =  ['#', 'boo', 'y', 'aa'] ; LogProb =  30328.417679897077
#
# .  #bradersisterhood
# MaxMatch =  ['#', 'brad', 'ers', 'ist', 'er', 'hood'] ; LogProb =  5810148.090612937
# Reversed MaxMatch =  ['#', 'brad', 'er', 'sisterhood'] ; LogProb =  36587.64564796326
#
# .  #bringithomemy
# MaxMatch =  ['#', 'bring', 'it', 'home', 'my'] ; LogProb =  -32418.984951584207
# Reversed MaxMatch =  ['#', 'brin', 'git', 'home', 'my'] ; LogProb =  -127786.62357496169
#
# .  #brooksengland
# MaxMatch =  ['#', 'brooks', 'en', 'gland'] ; LogProb =  21849.49643989781
# Reversed MaxMatch =  ['#', 'brook', 'sen', 'gland'] ; LogProb =  28981.35165403891
#
# .  #burgers
# MaxMatch =  ['#', 'burg', 'ers'] ; LogProb =  -2748.0961646085802
# Reversed MaxMatch =  ['#', 'bur', 'gers'] ; LogProb =  -2748.0961646085802
#
# .  #butitsalsokindofaphone
# MaxMatch =  ['#', 'but', 'its', 'also', 'kind', 'of', 'a', 'phone'] ; LogProb =  4105714.782504549
# Reversed MaxMatch =  ['#', 'bu', 'tits', 'also', 'kin', 'do', 'fa', 'phone'] ; LogProb =  218574984.40517646
#
# .  #cbcolympics
# MaxMatch =  ['#', 'c', 'b', 'coly', 'm', 'pics'] ; LogProb =  2640390.8600522806
# Reversed MaxMatch =  ['#', 'c', 'b', 'col', 'ym', 'pics'] ; LogProb =  3309887.7595309513
#
# .  #cdnpoli
# MaxMatch =  ['#', 'c', 'd', 'n', 'pol', 'i'] ; LogProb =  1026849.9392514277
# Reversed MaxMatch =  ['#', 'c', 'd', 'n', 'po', 'li'] ; LogProb =  2505137.100260472
#
# .  #ciosummit
# MaxMatch =  ['#', 'c', 'ios', 'um', 'mi', 't'] ; LogProb =  2726281.6090747705
# Reversed MaxMatch =  ['#', 'c', 'io', 'summit'] ; LogProb =  19637.022644780824
#
# .  #cleansidewalk
# MaxMatch =  ['#', 'cleans', 'ide', 'walk'] ; LogProb =  24532.470199200678
# Reversed MaxMatch =  ['#', 'clean', 'sidewalk'] ; LogProb =  -1492.0588610244774
#
# .  #coffeespoonart
# MaxMatch =  ['#', 'coffees', 'poon', 'art'] ; LogProb =  23811.232488487756
# Reversed MaxMatch =  ['#', 'coffee', 'spoon', 'art'] ; LogProb =  14107.309776768769
#
# .  #cornell
# MaxMatch =  ['#', 'cornel', 'l'] ; LogProb =  -2192.2338528498885
# Reversed MaxMatch =  ['#', 'cor', 'nell'] ; LogProb =  -2612.104148693726
#
# .  #cumannanya
# MaxMatch =  ['#', 'cum', 'anna', 'n', 'ya'] ; LogProb =  -300079.6243986587
# Reversed MaxMatch =  ['#', 'c', 'u', 'mannan', 'ya'] ; LogProb =  -254466.177938303
#
# .  #datingsiteforyou
# MaxMatch =  ['#', 'datings', 'it', 'e', 'for', 'you'] ; LogProb =  285217.81676025956
# Reversed MaxMatch =  ['#', 'dating', 'site', 'for', 'you'] ; LogProb =  -48924.53572222865
#
# .  #difd
# MaxMatch =  ['#', 'di', 'f', 'd'] ; LogProb =  15949.655401927517
# Reversed MaxMatch =  ['#', 'd', 'if', 'd'] ; LogProb =  8973.423915453423
#
# .  #endomondo
# MaxMatch =  ['#', 'end', 'om', 'on', 'do'] ; LogProb =  -55247.06231684032
# Reversed MaxMatch =  ['#', 'en', 'do', 'mon', 'do'] ; LogProb =  -102513.47277984908
#
# .  #excitables
# MaxMatch =  ['#', 'excitable', 's'] ; LogProb =  -2132.927855088645
# Reversed MaxMatch =  ['#', 'ex', 'c', 'i', 'tables'] ; LogProb =  -92625.88663717936
#
# .  #flambees
# MaxMatch =  ['#', 'flamb', 'e', 'es'] ; LogProb =  28287.227602861632
# Reversed MaxMatch =  ['#', 'flam', 'bees'] ; LogProb =  -2204.1281009491627
#
# .  #focusateneo
# MaxMatch =  ['#', 'focus', 'aten', 'e', 'o'] ; LogProb =  -222658.86656871953
# Reversed MaxMatch =  ['#', 'fo', 'c', 'u', 'sate', 'neo'] ; LogProb =  4027012.9717941205
#
# .  #foodporn
# MaxMatch =  ['#', 'food', 'po', 'r', 'n'] ; LogProb =  -179757.0850052951
# Reversed MaxMatch =  ['#', 'food', 'p', 'or', 'n'] ; LogProb =  -71423.99447022584
#
# .  #fotografías
# MaxMatch =  ['#', 'fot', 'og', 'ra', 'f', 'í', 'as'] ; LogProb =  -27265756.1945192
# Reversed MaxMatch =  ['#', 'f', 'oto', 'gra', 'f', 'í', 'as'] ; LogProb =  -21290367.34511751
#
# .  #fotorus
# MaxMatch =  ['#', 'fot', 'or', 'us'] ; LogProb =  8321.840152930281
# Reversed MaxMatch =  ['#', 'fo', 'torus'] ; LogProb =  -2748.0961646085802
#
# .  #getfreetattooaviciipasses
# MaxMatch =  ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passes'] ; LogProb =  891042037.8988951
# Reversed MaxMatch =  ['#', 'get', 'free', 'tattoo', 'a', 'vic', 'i', 'i', 'passes'] ; LogProb =  -190825172.15866193
#
# .  #goingout
# MaxMatch =  ['#', 'going', 'out'] ; LogProb =  -713.8554112393325
# Reversed MaxMatch =  ['#', 'go', 'in', 'gout'] ; LogProb =  5524.914045621026
#
# .  #google
# MaxMatch =  ['#', 'goo', 'g', 'l', 'e'] ; LogProb =  -252141.46278054063
# Reversed MaxMatch =  ['#', 'go', 'ogle'] ; LogProb =  -1484.41461323462
#
# .  #grammyfans
# MaxMatch =  ['#', 'gram', 'my', 'fans'] ; LogProb =  12109.734621845331
# Reversed MaxMatch =  ['#', 'g', 'rammy', 'fans'] ; LogProb =  23930.25012520229
#
# .  #grandmarnier
# MaxMatch =  ['#', 'grandma', 'r', 'ni', 'er'] ; LogProb =  -323128.85990094295
# Reversed MaxMatch =  ['#', 'grand', 'm', 'arni', 'er'] ; LogProb =  -310601.00802186196
#
# .  #happybirthdaysandarapark
# MaxMatch =  ['#', 'happy', 'birthdays', 'anda', 'rap', 'ark'] ; LogProb =  4676504.137815733
# Reversed MaxMatch =  ['#', 'happy', 'birthday', 'sand', 'ara', 'park'] ; LogProb =  2054558.3549476347
#
# .  #harimaumalaya
# MaxMatch =  ['#', 'ha', 'rima', 'um', 'ala', 'ya'] ; LogProb =  5452210.9861671105
# Reversed MaxMatch =  ['#', 'h', 'ar', 'i', 'mau', 'mala', 'ya'] ; LogProb =  -28201591.305732444
#
# .  #hometomama
# MaxMatch =  ['#', 'home', 'toma', 'ma'] ; LogProb =  16636.168341609264
# Reversed MaxMatch =  ['#', 'home', 'tom', 'ama'] ; LogProb =  14142.545015650394
#
# .  #ididntchoosethestudentlifeitchoseme
# MaxMatch =  ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me'] ; LogProb =  -13699650565398.143
# Reversed MaxMatch =  ['#', 'i', 'didnt', 'choose', 'the', 'student', 'life', 'it', 'cho', 'seme'] ; LogProb =  2017170406.6775377
#
# .  #imsobored
# MaxMatch =  ['#', 'i', 'ms', 'o', 'bored'] ; LogProb =  -119416.55033857425
# Reversed MaxMatch =  ['#', 'i', 'm', 'so', 'bored'] ; LogProb =  -61890.58226295736
#
# .  #imsosore
# MaxMatch =  ['#', 'i', 'ms', 'os', 'ore'] ; LogProb =  -184009.08254352803
# Reversed MaxMatch =  ['#', 'i', 'm', 'so', 'sore'] ; LogProb =  -63589.47752668876
#
# .  #innoretail
# MaxMatch =  ['#', 'inn', 'ore', 'tail'] ; LogProb =  24773.120681114473
# Reversed MaxMatch =  ['#', 'in', 'no', 'retail'] ; LogProb =  3930.7417226183134
#
# .  #insightmediasingapore
# MaxMatch =  ['#', 'insight', 'media', 'sing', 'a', 'pore'] ; LogProb =  923715.592293716
# Reversed MaxMatch =  ['#', 'insight', 'me', 'di', 'as', 'inga', 'pore'] ; LogProb =  -10618535.457435602
#
# .  #instagood
# MaxMatch =  ['#', 'ins', 'tag', 'o', 'od'] ; LogProb =  -359557.0033185734
# Reversed MaxMatch =  ['#', 'ins', 'ta', 'good'] ; LogProb =  20098.583655112823
#
# .  #instalook
# MaxMatch =  ['#', 'ins', 'tal', 'o', 'ok'] ; LogProb =  -359557.0033185734
# Reversed MaxMatch =  ['#', 'ins', 'ta', 'look'] ; LogProb =  22027.36001407357
#
# .  #isibaya
# MaxMatch =  ['#', 'is', 'iba', 'ya'] ; LogProb =  11640.370971875074
# Reversed MaxMatch =  ['#', 'i', 'si', 'baya'] ; LogProb =  14255.04229538436
#
# .  #jordaan
# MaxMatch =  ['#', 'jo', 'r', 'da', 'an'] ; LogProb =  -113464.06773835154
# Reversed MaxMatch =  ['#', 'j', 'or', 'da', 'an'] ; LogProb =  -62115.49532785537
#
# .  #jrsurfboards
# MaxMatch =  ['#', 'j', 'rs', 'urf', 'boards'] ; LogProb =  -335949.1408265889
# Reversed MaxMatch =  ['#', 'j', 'r', 'surfboards'] ; LogProb =  24475.77953833712
#
# .  #ladygaga
# MaxMatch =  ['#', 'lady', 'gag', 'a'] ; LogProb =  6602.180923844508
# Reversed MaxMatch =  ['#', 'lady', 'g', 'aga'] ; LogProb =  21072.87783055007
#
# .  #laundryservice
# MaxMatch =  ['#', 'laundrys', 'er', 'vice'] ; LogProb =  28221.00521379076
# Reversed MaxMatch =  ['#', 'laundry', 'service'] ; LogProb =  -1411.7665047312219
#
# .  #learningcommunties
# MaxMatch =  ['#', 'learning', 'c', 'om', 'munt', 'ies'] ; LogProb =  3505630.7091852985
# Reversed MaxMatch =  ['#', 'learning', 'c', 'om', 'm', 'unties'] ; LogProb =  2796540.534221369
#
# .  #lebedeintennis
# MaxMatch =  ['#', 'l', 'e', 'bed', 'e', 'in', 'tennis'] ; LogProb =  -6888225.908031261
# Reversed MaxMatch =  ['#', 'l', 'e', 'be', 'de', 'in', 'tennis'] ; LogProb =  -3526083.14525663
#
# .  #letmesleep
# MaxMatch =  ['#', 'let', 'mes', 'leep'] ; LogProb =  22132.395582431447
# Reversed MaxMatch =  ['#', 'let', 'me', 'sleep'] ; LogProb =  7676.99789757907
#
# .  #loadsoffun
# MaxMatch =  ['#', 'loads', 'off', 'un'] ; LogProb =  13947.921056794768
# Reversed MaxMatch =  ['#', 'loads', 'of', 'fun'] ; LogProb =  5812.370342044351
#
# .  #longranger
# MaxMatch =  ['#', 'long', 'ranger'] ; LogProb =  -1334.8779782137933
# Reversed MaxMatch =  ['#', 'l', 'on', 'granger'] ; LogProb =  11379.559083578337
#
# .  #magazinesandtvscreens
# MaxMatch =  ['#', 'magazines', 'and', 't', 'vs', 'creen', 's'] ; LogProb =  -10250165.513647813
# Reversed MaxMatch =  ['#', 'magazine', 'sand', 't', 'v', 'screens'] ; LogProb =  1838929.892722605
#
# .  #makeupfree
# MaxMatch =  ['#', 'make', 'up', 'free'] ; LogProb =  5602.805486209834
# Reversed MaxMatch =  ['#', 'ma', 'keup', 'free'] ; LogProb =  18246.910440790678
#
# .  #mamajeanneandme
# MaxMatch =  ['#', 'mam', 'a', 'jeanne', 'and', 'me'] ; LogProb =  281566.0339471495
# Reversed MaxMatch =  ['#', 'm', 'ama', 'jeanne', 'and', 'me'] ; LogProb =  756077.4196594126
#
# .  #meetup
# MaxMatch =  ['#', 'meet', 'up'] ; LogProb =  -814.2973541656567
# Reversed MaxMatch =  ['#', 'me', 'e', 'tup'] ; LogProb =  13999.255465047767
#
# .  #melbourne
# MaxMatch =  ['#', 'mel', 'bourn', 'e'] ; LogProb =  22669.672372353547
# Reversed MaxMatch =  ['#', 'm', 'elb', 'our', 'ne'] ; LogProb =  -181744.2051062456
#
# .  #mtlnewtech
# MaxMatch =  ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h'] ; LogProb =  204451680.10266227
# Reversed MaxMatch =  ['#', 'm', 't', 'l', 'new', 'tech'] ; LogProb =  1316806.8723411395
#
# .  #myfriendsarebetterthanyours
# MaxMatch =  ['#', 'my', 'friends', 'are', 'better', 'than', 'yours'] ; LogProb =  -2674570.391285105
# Reversed MaxMatch =  ['#', 'my', 'friend', 'sare', 'better', 'than', 'yours'] ; LogProb =  -6813988.136166124
#
# .  #nced
# MaxMatch =  ['#', 'n', 'ce', 'd'] ; LogProb =  20445.71425670532
# Reversed MaxMatch =  ['#', 'n', 'c', 'ed'] ; LogProb =  15157.042598099084
#
# .  #nevergetsold
# MaxMatch =  ['#', 'never', 'gets', 'old'] ; LogProb =  7692.622202448651
# Reversed MaxMatch =  ['#', 'never', 'get', 'sold'] ; LogProb =  7822.177430542398
#
# .  #nickryrie
# MaxMatch =  ['#', 'nick', 'r', 'yr', 'ie'] ; LogProb =  -305532.88022667705
# Reversed MaxMatch =  ['#', 'nick', 'r', 'y', 'rie'] ; LogProb =  -266449.3587658588
#
# .  #oilandgas
# MaxMatch =  ['#', 'oil', 'and', 'gas'] ; LogProb =  4646.9203446020665
# Reversed MaxMatch =  ['#', 'o', 'i', 'land', 'gas'] ; LogProb =  -66338.98004801858
#
# .  #olah
# MaxMatch =  ['#', 'o', 'la', 'h'] ; LogProb =  16306.22713609684
# Reversed MaxMatch =  ['#', 'o', 'l', 'ah'] ; LogProb =  18224.945802198174
#
# .  #openspace
# MaxMatch =  ['#', 'opens', 'pace'] ; LogProb =  -1599.9692243336908
# Reversed MaxMatch =  ['#', 'open', 'space'] ; LogProb =  -1014.3451489580088
#
# .  #palacefansinthemorning
# MaxMatch =  ['#', 'palace', 'fans', 'in', 'them', 'or', 'ning'] ; LogProb =  -3301753.1391939875
# Reversed MaxMatch =  ['#', 'palace', 'fan', 'sin', 'the', 'morning'] ; LogProb =  395996.1959861158
#
# .  #pechanga
# MaxMatch =  ['#', 'pech', 'an', 'ga'] ; LogProb =  15097.582097270159
# Reversed MaxMatch =  ['#', 'p', 'e', 'changa'] ; LogProb =  19514.861004916238
#
# .  #peperoni
# MaxMatch =  ['#', 'pep', 'er', 'on', 'i'] ; LogProb =  -77848.1869342677
# Reversed MaxMatch =  ['#', 'pep', 'e', 'ro', 'ni'] ; LogProb =  -396218.1448294687
#
# .  #photoby
# MaxMatch =  ['#', 'photo', 'by'] ; LogProb =  -929.0925279981143
# Reversed MaxMatch =  ['#', 'pho', 'toby'] ; LogProb =  -2748.0961646085802
#
# .  #pmattheashes
# MaxMatch =  ['#', 'p', 'matt', 'he', 'ashes'] ; LogProb =  -99775.64407741366
# Reversed MaxMatch =  ['#', 'p', 'mat', 'the', 'ashes'] ; LogProb =  -56854.29456981085
#
# .  #potd
# MaxMatch =  ['#', 'pot', 'd'] ; LogProb =  -1501.4918440906833
# Reversed MaxMatch =  ['#', 'po', 'td'] ; LogProb =  -2612.1041486937256
#
# .  #rainorshine
# MaxMatch =  ['#', 'rain', 'ors', 'hin', 'e'] ; LogProb =  -275638.7489494628
# Reversed MaxMatch =  ['#', 'r', 'ai', 'nor', 'shine'] ; LogProb =  -205668.3770207179
#
# .  #reachingyougpeople
# MaxMatch =  ['#', 'reaching', 'you', 'g', 'people'] ; LogProb =  -68678.91648153165
# Reversed MaxMatch =  ['#', 'reaching', 'yo', 'ug', 'people'] ; LogProb =  -204071.04972041002
#
# .  #ritenow
# MaxMatch =  ['#', 'rite', 'now'] ; LogProb =  -1129.043046389297
# Reversed MaxMatch =  ['#', 'rit', 'enow'] ; LogProb =  -2748.0961646085802
#
# .  #samsung
# MaxMatch =  ['#', 'sams', 'un', 'g'] ; LogProb =  24921.107214456366
# Reversed MaxMatch =  ['#', 'sam', 'sung'] ; LogProb =  -1491.4065712651293
#
# .  #scifigeek
# MaxMatch =  ['#', 's', 'c', 'if', 'i', 'geek'] ; LogProb =  676072.2884525721
# Reversed MaxMatch =  ['#', 's', 'c', 'i', 'fi', 'geek'] ; LogProb =  1500461.4297941453
#
# .  #seniorbabysenior
# MaxMatch =  ['#', 'senior', 'babys', 'en', 'io', 'r'] ; LogProb =  3368119.1737972572
# Reversed MaxMatch =  ['#', 'senior', 'baby', 'senior'] ; LogProb =  15092.328686749217
#
# .  #shopaholic
# MaxMatch =  ['#', 'shop', 'aho', 'li', 'c'] ; LogProb =  -249063.539157851
# Reversed MaxMatch =  ['#', 'sho', 'paho', 'li', 'c'] ; LogProb =  -354244.05852688686
#
# .  #siberuang
# MaxMatch =  ['#', 'sib', 'er', 'uang'] ; LogProb =  38492.4807563693
# Reversed MaxMatch =  ['#', 'si', 'ber', 'uang'] ; LogProb =  36587.64564796326
#
# .  #singapore
# MaxMatch =  ['#', 'sing', 'a', 'pore'] ; LogProb =  7474.284170242685
# Reversed MaxMatch =  ['#', 's', 'inga', 'pore'] ; LogProb =  27532.580374979116
#
# .  #skeemsaam
# MaxMatch =  ['#', 'skee', 'ms', 'aam'] ; LogProb =  35473.38853948862
# Reversed MaxMatch =  ['#', 's', 'k', 'e', 'ems', 'aam'] ; LogProb =  3570063.473487032
#
# .  #skullsearcher
# MaxMatch =  ['#', 'skulls', 'ear', 'che', 'r'] ; LogProb =  -264072.17904592556
# Reversed MaxMatch =  ['#', 'skull', 'searcher'] ; LogProb =  -2476.112132778872
#
# .  #socal
# MaxMatch =  ['#', 'soc', 'al'] ; LogProb =  -2108.8738916523234
# Reversed MaxMatch =  ['#', 'so', 'cal'] ; LogProb =  -1195.9513322881144
#
# .  #southampton
# MaxMatch =  ['#', 'south', 'am', 'p', 'ton'] ; LogProb =  -111913.20260491657
# Reversed MaxMatch =  ['#', 's', 'out', 'ham', 'p', 'ton'] ; LogProb =  1171125.1534367863
#
# .  #startupfest
# MaxMatch =  ['#', 'start', 'up', 'fest'] ; LogProb =  11364.260760514702
# Reversed MaxMatch =  ['#', 'star', 'tup', 'fest'] ; LogProb =  29538.918156307973
#
# .  #startuphub
# MaxMatch =  ['#', 'start', 'up', 'hub'] ; LogProb =  9348.18293328216
# Reversed MaxMatch =  ['#', 'star', 'tup', 'hub'] ; LogProb =  24298.563399376817
#
# .  #statoftheday
# MaxMatch =  ['#', 'st', 'at', 'oft', 'he', 'day'] ; LogProb =  512170.0551654786
# Reversed MaxMatch =  ['#', 's', 'tat', 'of', 'the', 'day'] ; LogProb =  151374.65319522403
#
# .  #strictlyus
# MaxMatch =  ['#', 'strictly', 'us'] ; LogProb =  -1099.6555298902988
# Reversed MaxMatch =  ['#', 'strict', 'l', 'yus'] ; LogProb =  25259.04155321351
#
# .  #surfshop
# MaxMatch =  ['#', 'surfs', 'hop'] ; LogProb =  -2532.5539189860615
# Reversed MaxMatch =  ['#', 'surf', 'shop'] ; LogProb =  -1836.5301781714604
#
# .  #swedumtl
# MaxMatch =  ['#', 's', 'wed', 'um', 't', 'l'] ; LogProb =  2627698.9155242825
# Reversed MaxMatch =  ['#', 's', 'we', 'dum', 't', 'l'] ; LogProb =  1408363.3902857364
#
# .  #takeabreak
# MaxMatch =  ['#', 'take', 'ab', 'reak'] ; LogProb =  18798.311125999597
# Reversed MaxMatch =  ['#', 'ta', 'kea', 'break'] ; LogProb =  26157.276364385827
#
# .  #thankyoulord
# MaxMatch =  ['#', 'thank', 'youl', 'or', 'd'] ; LogProb =  -116362.23028231367
# Reversed MaxMatch =  ['#', 'thank', 'you', 'lord'] ; LogProb =  8143.3420362192055
#
# .  #thankyoupatients
# MaxMatch =  ['#', 'thank', 'youp', 'ati', 'en', 'ts'] ; LogProb =  4773030.909683218
# Reversed MaxMatch =  ['#', 'thank', 'you', 'patients'] ; LogProb =  8945.638116290751
#
# .  #thenext5goldenyears
# MaxMatch =  ['#', 'then', 'ex', 't', '5', 'golden', 'years'] ; LogProb =  -7833134.022271361
# Reversed MaxMatch =  ['#', 'the', 'next', '5', 'golden', 'years'] ; LogProb =  212399.2199059777
#
# .  #thevoiceau
# MaxMatch =  ['#', 'the', 'voice', 'a', 'u'] ; LogProb =  -15409.885332663029
# Reversed MaxMatch =  ['#', 'the', 'v', 'o', 'i', 'c', 'ea', 'u'] ; LogProb =  36515782.19618459
#
# .  #thewalkingdead
# MaxMatch =  ['#', 'thew', 'alk', 'ing', 'dead'] ; LogProb =  -340357.3214324579
# Reversed MaxMatch =  ['#', 'the', 'walking', 'dead'] ; LogProb =  3531.0300901702917
#
# .  #toronto
# MaxMatch =  ['#', 'toro', 'n', 'to'] ; LogProb =  7782.485109316145
# Reversed MaxMatch =  ['#', 'tor', 'onto'] ; LogProb =  -1941.5632382119074
#
# .  #txlege
# MaxMatch =  ['#', 't', 'x', 'leg', 'e'] ; LogProb =  -155208.02544169553
# Reversed MaxMatch =  ['#', 't', 'x', 'l', 'e', 'ge'] ; LogProb =  2254549.304846317
#
# .  #uniexamonasaturday
# MaxMatch =  ['#', 'unie', 'x', 'am', 'ona', 'saturday'] ; LogProb =  2578923.436837411
# Reversed MaxMatch =  ['#', 'u', 'ni', 'ex', 'a', 'mona', 'saturday'] ; LogProb =  -15610772.684392532
#
# .  #uptonogood
# MaxMatch =  ['#', 'up', 'ton', 'og', 'o', 'od'] ; LogProb =  2162326.6265658042
# Reversed MaxMatch =  ['#', 'up', 'to', 'no', 'good'] ; LogProb =  -16091.555676698781
#
# .  #usydhereicome
# MaxMatch =  ['#', 'us', 'y', 'd', 'here', 'i', 'come'] ; LogProb =  -3934462.969948308
# Reversed MaxMatch =  ['#', 'u', 'syd', 'here', 'i', 'come'] ; LogProb =  679566.2099003512
#
# .  #usydoweek
# MaxMatch =  ['#', 'us', 'y', 'dow', 'e', 'e', 'k'] ; LogProb =  -19544311.08900072
# Reversed MaxMatch =  ['#', 'us', 'y', 'do', 'week'] ; LogProb =  -72970.4791275485
#
# .  #vegan
# MaxMatch =  ['#', 'vega', 'n'] ; LogProb =  -2029.323661944659
# Reversed MaxMatch =  ['#', 'v', 'e', 'gan'] ; LogProb =  21557.801050852377
#
# .  #veganfood
# MaxMatch =  ['#', 'vega', 'n', 'food'] ; LogProb =  18283.699936923535
# Reversed MaxMatch =  ['#', 'v', 'e', 'gan', 'food'] ; LogProb =  -194230.40942417624
#
# .  #vscocam
# MaxMatch =  ['#', 'vs', 'coca', 'm'] ; LogProb =  27178.27375635248
# Reversed MaxMatch =  ['#', 'vs', 'c', 'o', 'cam'] ; LogProb =  -227899.4628972981
#
# .  #weare90s
# MaxMatch =  ['#', 'wear', 'e', '9', '0', 's'] ; LogProb =  1752006.0062155675
# Reversed MaxMatch =  ['#', 'we', 'are', '9', '0', 's'] ; LogProb =  561831.0334199468
#
# .  #wearesocial
# MaxMatch =  ['#', 'weares', 'o', 'c', 'i', 'al'] ; LogProb =  1134463.2467504859
# Reversed MaxMatch =  ['#', 'we', 'are', 'social'] ; LogProb =  3886.3608295031663
#
# .  #wok
# MaxMatch =  ['#', 'wo', 'k'] ; LogProb =  -2277.6410848705063
# Reversed MaxMatch =  ['#', 'w', 'ok'] ; LogProb =  -2089.9956228680053
#
# .  #yiamas
# MaxMatch =  ['#', 'y', 'i', 'ama', 's'] ; LogProb =  -135149.19113618234
# Reversed MaxMatch =  ['#', 'y', 'i', 'a', 'mas'] ; LogProb =  -51729.48565996569

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this (but if you don't want to use sklearn that's fine).
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
from sklearn.feature_extraction import DictVectorizer

x_train, x_dev, x_test = None, None, None
y_train, y_dev, y_test = None, None, None

###
# Your answer BEGINS HERE
###
from sklearn.model_selection import train_test_split
# firstly have 2 partitions with 70%/30% ratio, then evenly partition the one with 30% ratio
# follow convention of value of random state, which is 42
x_train, x_dev_test, y_train, y_dev_test = train_test_split(x_processed,y_processed,test_size=0.3,random_state=42,stratify=y_processed)
x_dev, x_test, y_dev, y_test = train_test_split(x_dev_test,y_dev_test,test_size=0.5,random_state=42,stratify=y_dev_test)
# turn the bag-of-words dictionary of each tweet into a feature vector
vector = DictVectorizer()
x_train = vector.fit_transform(x_train)
x_dev = vector.transform(x_dev)
x_test = vector.transform(x_test)

###
# Your answer ENDS HERE
###

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

###
# Your answer BEGINS HERE
###
from sklearn.metrics import accuracy_score
# MultinomialNB
print("MultinomialNB")
# case 1
clf = MultinomialNB(alpha=0.1)
clf.fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("alpha=0.1, accuracy is ", accuracy_score(y_dev, y_pred))
# case 2
clf = MultinomialNB(alpha=0.01)
clf.fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("alpha=0.01, accuracy is ", accuracy_score(y_dev, y_pred))
# case 3, default choice
clf = MultinomialNB(alpha=1)
clf.fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("alpha=1, accuracy is ", accuracy_score(y_dev, y_pred))
# case 4
clf = MultinomialNB(alpha=0.05)
clf.fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("alpha=0.05, accuracy is ", accuracy_score(y_dev, y_pred))
# case 5
clf = MultinomialNB(alpha=0.001)
clf.fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("alpha=0.001, accuracy is ", accuracy_score(y_dev, y_pred))
# case 6
clf = MultinomialNB(alpha=0.08)
clf.fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("alpha=0.08, accuracy is ", accuracy_score(y_dev, y_pred))
print("Alpha is additive smoothing parameter, a optimal choice for alpha is 0.05")

print()
# LogisticRegression
print("LogisticRegression")
# case 1, takes default value of C
clf = LogisticRegression(C=1).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=1, accuracy is ", accuracy_score(y_dev, y_pred))
# case 2
clf = LogisticRegression(C=5).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=5, accuracy is ", accuracy_score(y_dev, y_pred))
# case 3
clf = LogisticRegression(C=0.5).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=0.5, accuracy is ", accuracy_score(y_dev, y_pred))
# case 4
clf = LogisticRegression(C=10).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=10, accuracy is ", accuracy_score(y_dev, y_pred))
# case 5
clf = LogisticRegression(C=0.1).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=0.1, accuracy is ", accuracy_score(y_dev, y_pred))
# case 6
clf = LogisticRegression(C=7).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=7, accuracy is ", accuracy_score(y_dev, y_pred))
# case 7
clf = LogisticRegression(C=3).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=3, accuracy is ", accuracy_score(y_dev, y_pred))
# case 8
clf = LogisticRegression(C=1.5).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=1.5, accuracy is ", accuracy_score(y_dev, y_pred))
# case 9
clf = LogisticRegression(C=2).fit(x_dev, y_dev)
y_pred = clf.predict(x_dev)
print("C=2, accuracy is ", accuracy_score(y_dev, y_pred))
print("C is inverse of regularization strength, a optimal choice for C is 2")
    
###
# Your answer ENDS HERE
###
# Out:
# MultinomialNB
# alpha=0.1, accuracy is  0.8723404255319149
# alpha=0.01, accuracy is  0.8723404255319149
# alpha=1, accuracy is  0.8439716312056738
# alpha=0.05, accuracy is  0.8723404255319149
# alpha=0.001, accuracy is  0.8652482269503546
# alpha=0.08, accuracy is  0.8723404255319149
# Alpha is additive smoothing parameter, a optimal choice for alpha is 0.05
#
# LogisticRegression
# C=1, accuracy is  0.900709219858156
# C=5, accuracy is  0.9290780141843972
# C=0.5, accuracy is  0.8581560283687943
# C=10, accuracy is  0.9290780141843972
# C=0.1, accuracy is  0.7801418439716312
# C=7, accuracy is  0.9290780141843972
# C=3, accuracy is  0.9290780141843972
# C=1.5, accuracy is  0.9148936170212766
# C=2, accuracy is  0.9290780141843972
# C is inverse of regularization strength, a optimal choice for C is 2

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
###
# Your answer BEGINS HERE
###
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
# MultinomialNB
clf1 = MultinomialNB(alpha=0.05).fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("Performance of MultinomialNB:")
print("accuracy is ", accuracy_score(y_test, y_pred))
print("macro-averaged F-score is ", f1_score(y_test, y_pred, average='macro'))
print()
# LogisticRegression
print("Performance of LogisticRegression:")
clf2 = LogisticRegression(C=2).fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("accuracy is ", accuracy_score(y_test, y_pred))
print("macro-averaged F-score is ", f1_score(y_test, y_pred, average='macro'))
print()
print("Performance of Naive Bayes(MultinomialNB) is better than Logistic Regression on accuracy and macro-averaged F-score.")



###
# Your answer ENDS HERE
###
# Out:
# Performance of MultinomialNB:
# accuracy is  0.20422535211267606
# macro-averaged F-score is  0.18529774188535986
#
# Performance of LogisticRegression:
# accuracy is  0.20422535211267606
# macro-averaged F-score is  0.18529774188535986
#
# Performance of Naive Bayes(MultinomialNB) is better than Logistic Regression on accuracy and macro-averaged F-score.

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
###
# Your answer BEGINS HERE
###
# trend/pattern: the words are ranked in weight from the highest to the lowestest, so the words with higher weight are more
# important than the words with the lower weight when classify.

# refer from sklearn.naive_bayes.MultinomialNB and sklearn.linear_model.LogisticRegression
# Naive Bayes
print("Classifier = Naive Bayes")
print()
# feature_log_prob_ is empirical log probability of features given a class, P(x_i|y), which's suitable for the weight
feature_weight1 = clf1.feature_log_prob_
classes1 = clf1.classes_
for i in feature_weight1:
  i.sort()
  i[:] = i[::-1]
for x, y in zip(classes1,feature_weight1):
  print("Country = ", x)
  print(y[:20])
  print()

print()
# Logistic Regression
print("Classifier = Logistic Regression")
print()
# coef_ is coefficient of the features in the decision function, which's suitable for the weight
feature_weight2 = clf2.coef_
classes2 = clf2.classes_
for j in feature_weight2:
  j.sort()
  j[:] = j[::-1]
for m, n in zip(classes2,feature_weight2):
  print("Country = ", m)
  print(n[:20])
  print() 
     
###
# Your answer ENDS HERE
###
# Out:
# Classifier = Naive Bayes
#
# Country =  au
# [-4.78307429 -4.96374432 -4.96374432 -4.96374432 -5.18441568 -5.18441568
#  -5.46799097 -5.46799097 -5.46799097 -5.46799097 -5.46799097 -5.86529277
#  -5.86529277 -5.86529277 -5.86529277 -5.86529277 -5.86529277 -5.86529277
#  -5.86529277 -5.86529277]
#
# Country =  ca
# [-4.98021011 -4.98021011 -5.20088147 -5.20088147 -5.20088147 -5.20088147
#  -5.20088147 -5.48445676 -5.48445676 -5.48445676 -5.48445676 -5.48445676
#  -5.48445676 -5.48445676 -5.48445676 -5.88175856 -5.88175856 -5.88175856
#  -5.88175856 -5.88175856]
#
# Country =  de
# [-4.66227373 -4.94584902 -4.94584902 -5.34315082 -5.34315082 -5.34315082
#  -5.34315082 -5.34315082 -5.34315082 -5.34315082 -5.34315082 -5.34315082
#  -5.34315082 -5.34315082 -5.34315082 -5.34315082 -5.34315082 -5.34315082
#  -5.34315082 -6.01220045]
#
# Country =  gb
# [-4.90241039 -4.90241039 -5.12308176 -5.12308176 -5.40665705 -5.40665705
#  -5.40665705 -5.40665705 -5.40665705 -5.40665705 -5.40665705 -5.80395884
#  -5.80395884 -5.80395884 -5.80395884 -5.80395884 -5.80395884 -5.80395884
#  -5.80395884 -5.80395884]
#
# Country =  id
# [-4.21690438 -4.61961087 -5.30452755 -5.30452755 -5.30452755 -5.30452755
#  -5.30452755 -5.70182935 -5.70182935 -5.70182935 -5.70182935 -5.70182935
#  -5.70182935 -5.70182935 -5.70182935 -5.70182935 -5.70182935 -5.70182935
#  -5.70182935 -5.70182935]
#
# Country =  my
# [-3.71471115 -4.53739238 -4.87103176 -5.09170312 -5.09170312 -5.09170312
#  -5.09170312 -5.09170312 -5.09170312 -5.09170312 -5.37527841 -5.37527841
#  -5.37527841 -5.37527841 -5.37527841 -5.37527841 -5.77258021 -5.77258021
#  -5.77258021 -5.77258021]
#
# Country =  ph
# [-4.71435808 -4.89502811 -5.11569947 -5.11569947 -5.11569947 -5.11569947
#  -5.11569947 -5.11569947 -5.11569947 -5.39927476 -5.39927476 -5.39927476
#  -5.39927476 -5.39927476 -5.39927476 -5.39927476 -5.39927476 -5.39927476
#  -5.39927476 -5.39927476]
#
# Country =  sg
# [-4.01070061 -4.46010342 -4.79374279 -5.01441415 -5.29798944 -5.29798944
#  -5.69529124 -5.69529124 -5.69529124 -5.69529124 -5.69529124 -5.69529124
#  -5.69529124 -5.69529124 -5.69529124 -5.69529124 -5.69529124 -5.69529124
#  -5.69529124 -5.69529124]
#
# Country =  us
# [-4.66421846 -4.84488849 -5.06555985 -5.06555985 -5.06555985 -5.06555985
#  -5.34913514 -5.34913514 -5.34913514 -5.34913514 -5.34913514 -5.34913514
#  -5.34913514 -5.74643694 -5.74643694 -5.74643694 -5.74643694 -5.74643694
#  -5.74643694 -5.74643694]
#
# Country =  za
# [-4.72906855 -4.90973858 -5.13040994 -5.13040994 -5.13040994 -5.13040994
#  -5.13040994 -5.13040994 -5.41398523 -5.41398523 -5.41398523 -5.41398523
#  -5.41398523 -5.41398523 -5.81128703 -5.81128703 -5.81128703 -5.81128703
#  -5.81128703 -5.81128703]
#
#
# Classifier = Logistic Regression
#
# Country =  au
# [1.38403763 1.32524247 1.21690819 1.2124505  1.07124888 0.91301456
#  0.91301456 0.9103095  0.89146067 0.89146067 0.87146912 0.84217587
#  0.83932823 0.83509352 0.83509352 0.81585589 0.79277036 0.79277036
#  0.78279875 0.76497868]
#
# Country =  ca
# [1.17081531 1.08350681 1.0622559  1.03910189 1.02111806 0.99072889
#  0.94102229 0.92972447 0.89369718 0.8914     0.87140169 0.87140169
#  0.82097599 0.80837894 0.79731022 0.79731022 0.78257528 0.78212958
#  0.77550227 0.77462782]
#
# Country =  de
# [1.06098815 1.06098815 0.98962088 0.94644487 0.94283063 0.93202267
#  0.93202267 0.93202267 0.93202267 0.93202267 0.93202267 0.82432141
#  0.82432141 0.82402873 0.82402873 0.81788424 0.81634359 0.81634359
#  0.81352782 0.80107813]
#
# Country =  gb
# [1.46395205 1.19190044 1.02358232 1.01430187 1.00008495 0.99176849
#  0.97139114 0.97139114 0.97139114 0.97139114 0.97090043 0.95003116
#  0.89469878 0.88090912 0.87257153 0.86146117 0.84197185 0.83784235
#  0.83784235 0.8198136 ]
#
# Country =  id
# [1.70120194 1.08894724 1.05514166 1.02327546 0.97916536 0.97220408
#  0.95436256 0.94316614 0.90103203 0.90103203 0.90103203 0.90103203
#  0.83838589 0.82323472 0.81930228 0.80127417 0.79661115 0.76135373
#  0.73264709 0.72823358]
#
# Country =  my
# [1.44484317 1.2553266  1.19666202 1.07504763 1.03929484 1.00480575
#  0.9990938  0.9990938  0.97794577 0.94547611 0.93314874 0.93118545
#  0.91620948 0.91620948 0.91004799 0.87501031 0.87501031 0.87229665
#  0.87199787 0.84956123]
#
# Country =  ph
# [1.21394499 1.12254268 1.03202332 1.02486337 1.0135625  1.01140175
#  0.98255379 0.97294785 0.97294785 0.94921378 0.92191407 0.90548914
#  0.90399976 0.86328077 0.842447   0.842447   0.842447   0.82292981
#  0.81568026 0.81354141]
#
# Country =  sg
# [2.54306454 1.57425066 1.10127915 0.99356247 0.99356247 0.92673833
#  0.92673833 0.89631286 0.86454831 0.86454831 0.83646437 0.83382549
#  0.82948183 0.82259698 0.82105854 0.82105854 0.80413691 0.80413691
#  0.78079654 0.77548852]
#
# Country =  us
# [1.22727223 1.19423287 1.11159311 1.10057541 0.96297266 0.96297266
#  0.95972773 0.92130364 0.91572883 0.91572883 0.89503253 0.87198466
#  0.8692336  0.8692336  0.85711109 0.82030042 0.79254299 0.79254299
#  0.78962809 0.78736332]
#
# Country =  za
# [1.53201662 1.19767262 1.06125171 1.05328012 1.02778555 0.95235255
#  0.93810965 0.93810965 0.88594851 0.87881596 0.86795226 0.8557975
#  0.8557975  0.81005122 0.80730409 0.79235291 0.79213499 0.79005114
#  0.78592028 0.78592028]
